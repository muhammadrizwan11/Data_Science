# %% [markdown]
# # Python Tuples
# mytuple = ("apple", "banana", "cherry")
# ## Tuple
# Tuples are used to store multiple items in a single variable.
#
# Tuple is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Set, and Dictionary, all with different qualities and usage.
#
# A tuple is a collection which is ordered and unchangeable.
#
# Tuples are written with round brackets.
#
# ## Example
# Create a Tuple:

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %% [markdown]
# # Tuple Items - Data Types
# Tuple items can be of any data type:
#
# ## Example
# String, int and boolean data types:

# %%
tuple1 = ("apple", "banana", "cherry")
tuple2 = (1, 5, 7, 9, 3)
tuple3 = (True, False, False)

print(tuple1)
print(tuple2)
print(tuple3)
# Out:
# ('apple', 'banana', 'cherry')
# (1, 5, 7, 9, 3)
# (True, False, False)

# %% [markdown]
# # type()

# %% [markdown]
# # Example
# What is the data type of a tuple?

# %%
mytuple = ("apple", "banana", "cherry")
print(type(mytuple))
# Out:
# <class 'tuple'>

# %% [markdown]
# ![Python-tuple-methods-1024x576.webp](attachment:Python-tuple-methods-1024x576.webp)

# %% [markdown]
# # Python Tuple count() Method
#
# ## Example
# Return the number of times the value 5 appears in the tuple:

# %%
thistuple = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)

x = thistuple.count(5)

print(x)
# Out:
# 2

# %% [markdown]
# # Python Tuple index() Method
#
# ## Example
# Search for the first occurrence of the value 8, and return its position:

# %%
thistuple = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)

x = thistuple.index(8)

print(x)
# Out:
# 3

# %% [markdown]
# # Access Tuple Items
# You can access tuple items by referring to the index number, inside square brackets:

# %% [markdown]
# ![tuple1%20indes.png](attachment:tuple1%20indes.png)

# %% [markdown]
# # Example
# Print the second item in the tuple:

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[1])
# Out:
# banana

# %%
thistuple[0]
# Out:
# 'apple'

# %%
thistuple[2]
# Out:
# 'cherry'

# %%
thistuple[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 thistuple[5]
#
# IndexError: tuple index out of range

# %% [markdown]
# # Negative Indexing
# Negative indexing means start from the end.
#
# -1 refers to the last item, -2 refers to the second last item etc.
#
# ## Example
# Print the last item of the tuple:

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[-1])
# Out:
# cherry

# %%
thistuple[-2]
# Out:
# 'banana'

# %% [markdown]
# # Python - Update Tuples
# Tuples are unchangeable, meaning that you cannot change, add, or remove items once the tuple is created.
#
# But there are some workarounds.
#
# ## Change Tuple Values
# Once a tuple is created, you cannot change its values. Tuples are unchangeable, or immutable as it also is called.
#
# But there is a workaround. You can convert the tuple into a list, change the list, and convert the list back into a tuple.
#
# ## Example
# Convert the tuple into a list to be able to change it:

# %%
x = ("apple", "banana", "cherry")
y = list(x)

# %%
y
# Out:
# ['apple', 'banana', 'cherry']

# %%
y[1]='melon'

# %%
y
# Out:
# ['apple', 'melon', 'cherry']

# %%
x = tuple(y)
x
# Out:
# ('apple', 'melon', 'cherry')

# %% [markdown]
# # Remove Items

# %% [markdown]
# ## Example
# Convert the tuple into a list, remove "apple", and convert it back into a tuple:

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.remove("apple")
print(y)
thistuple = tuple(y)
print(thistuple)
# Out:
# ['banana', 'cherry']
# ('banana', 'cherry')

# %% [markdown]
# # Try Yourself

# %% [markdown]
# ### sort(), copy(), append(), clear(), reverse(), remove(), pop(), insert(), count(), extend() and index()

# %% [markdown]
# ![lm1.jpg](attachment:lm1.jpg)

# %% [markdown]
# # Tuples Functions

# %% [markdown]
# ![python-tuple-functions.webp](attachment:python-tuple-functions.webp)

# %%
t = (2,7,4,9,6,1,5,0,8)

# %%
len(t)
# Out:
# 9

# %%
max(t)
# Out:
# 9

# %%
min(t)
# Out:
# 0

# %%
sum(t)
# Out:
# 42

# %%
sorted(t)
# Out:
# [0, 1, 2, 4, 5, 6, 7, 8, 9]

# %%
1. Write a Python program to create a tuple.
2. Write a Python program to add an item to a tuple.
