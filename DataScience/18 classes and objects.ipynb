# %% [markdown]
# # oop in python

# %% [markdown]
# ![R.png](attachment:R.png)

# %% [markdown]
# ## class and object
# class is the buluprint of variables and methods/functions
# we make object to use class variables and mathods/functions

# %%
class student:
    name = 'ali'
    id = 2
    def sumvale(self):
        print(30+20)
obj = student()
print(obj.name)
print(obj.id)
print(obj.sumvale(z)
# Out:
# ali
# 2
# 50
# None
